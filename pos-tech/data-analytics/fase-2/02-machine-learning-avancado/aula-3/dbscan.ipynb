# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score

# %%
df = pd.read_csv('dados/mall.csv')

# %%
dbs = DBSCAN(eps=10, min_samples=8)

dbs.fit(df[['Annual Income (k$)', 'Spending Score (1-100)']])
# Out:
# DBSCAN(eps=10, min_samples=8)

# %%
plt.scatter(df['Annual Income (k$)'], df['Spending Score (1-100)'],
            c=dbs.labels_, alpha=0.5, cmap='rainbow')
plt.show()

# %%
silhouette_score(df[['Annual Income (k$)', 'Spending Score (1-100)']],
                 dbs.labels_)
# Out:
# np.float64(0.36328873885121793)
